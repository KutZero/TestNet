# %%
import numpy as np
import re
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import Dense, LSTM, Input, Dropout, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow import keras

# %%
# детерминация случайных величин, отвечающих за выбор первоначальных весов и биасов
tf.compat.v1.set_random_seed(290)
tf.random.set_seed(290)
np.random.seed(400)

# %%
#///////////////////////////////// для колбэков

    # для Early_stopping
ES_patience = 20 # кол-во эпох без улучшений
ES_min_delta = 0.001 # минимальное улучшение параметра за cur_patience
ES_monitor_parametr =  'loss' # отслеживаемый параметр 
ES_save_best_weights = True # сохранять ли веса нейронки с лучшими результатами
    
    # для ReduceLROnPlateau
RLPOP_monitor_parametr = 'val_loss'  # отслеживаемый параметр 
RLPOP_factor = 0.1 # множитель для расчета нового шага сходимости (new_learning_rate = old_learning_rate*RLPOP_factor)
RLPOP_patience = 10 # кол-во эпох без улучшений
RLPOP_verbose = 1 # выводить ли прогресс изменения шага сходимости в его процессее
RLPOP_mode = 'auto' # выбирает, уменьшать шаг сходимости при росте величины или при её уменьшении
RLPOP_min_delta = 0.0001 # порог изменения отслеживаемого значения
RLPOP_cooldown = 0 # количество эпох до возобновления работы после изменения шага сходимости
RLPOP_min_lr = 0 # минимальное значение шага сходимости

    # для CallbackList
CBL_add_history = True # вызывать ли колбэк History (если он не был довавлен вручную)
CBL_add_progbar = True # вызывать ли колбэк ProgbarLogger (если он не был довавлен вручную)

# %%
def sequence_to_text(list_of_indices):
    words = [reverse_word_map.get(letter) for letter in list_of_indices]
    return(words)

# %%
# разделить данные на тренировочные и тестовые
def split(X,Y,factor):
    X_train=X[:factor]
    Y_train=Y[:factor]
    X_test=X[factor:]
    Y_test=Y[factor:]
    return X_train,Y_train,X_test,Y_test

# %%
with open('train_data_true', 'r', encoding='utf-8') as f:
    texts_true = f.readlines()
    texts_true[0] = texts_true[0].replace('\ufeff', '') #убираем первый невидимый символ

with open('train_data_false', 'r', encoding='utf-8') as f:
    texts_false = f.readlines()
    texts_false[0] = texts_false[0].replace('\ufeff', '') #убираем первый невидимый символ

# %%
texts = texts_true + texts_false
count_true = len(texts_true)
count_false = len(texts_false)
total_lines = count_true + count_false
print(count_true, count_false, total_lines)
# Out:
# 84 88 172

# %%
maxWordsCount = 1000
tokenizer = Tokenizer(num_words=maxWordsCount, 
                      filters='!–"—#$%&amp;()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»', 
                      lower=True, 
                      split=' ', 
                      char_level=False)

tokenizer.fit_on_texts(texts)

reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))
print(reverse_word_map)
# Out:
# {1: 'не', 2: 'и', 3: 'в', 4: 'вы', 5: 'на', 6: 'я', 7: 'а', 8: 'только', 9: 'что', 10: 'все', 11: 'это', 12: 'если', 13: 'жизнь', 14: 'просто', 15: 'с', 16: 'чем', 17: 'никогда', 18: 'чтобы', 19: 'к', 20: 'у', 21: 'больше', 22: 'себя', 23: 'то', 24: 'всегда', 25: 'вас', 26: 'меня', 27: 'за', 28: 'вам', 29: 'когда', 30: 'от', 31: 'мне', 32: 'быть', 33: 'жизни', 34: 'есть', 35: 'но', 36: 'сделать', 37: 'без', 38: 'позитивным', 39: 'никому', 40: 'как', 41: 'ты', 42: 'тем', 43: 'для', 44: 'день', 45: 'позитивное', 46: 'своих', 47: 'мы', 48: 'много', 49: 'тебя', 50: 'никто', 51: 'такой', 52: 'деньги', 53: 'денег', 54: 'позитивно', 55: 'свою', 56: 'которые', 57: 'значит', 58: 'так', 59: 'них', 60: 'мечты', 61: 'нужно', 62: 'того', 63: 'ничего', 64: 'лучше', 65: 'надо', 66: 'верьте', 67: 'понедельник', 68: 'живи', 69: 'позволяйте', 70: 'хорошее', 71: 'можете', 72: 'ваши', 73: 'других', 74: 'делай', 75: 'тебе', 76: 'можешь', 77: 'успеха', 78: 'ваша', 79: 'стоит', 80: 'себе', 81: 'своей', 82: 'их', 83: 'позитив', 84: 'свои', 85: 'о', 86: 'энергию', 87: 'более', 88: 'делать', 89: 'по', 90: 'или', 91: 'нет', 92: 'кто', 93: 'во', 94: 'успеху', 95: 'пусть', 96: 'опасно', 97: 'равно', 98: 'ни', 99: 'же', 100: 'сама', 101: 'болезней', 102: 'подняться', 103: 'жизнью', 104: 'времена', 105: 'величайшим', 106: 'вашей', 107: 'продолжайте', 108: 'двигаться', 109: 'конце', 110: 'сильных', 111: 'людей', 112: 'свет', 113: 'может', 114: 'до', 115: 'настроены', 116: 'иметь', 117: 'хорошую', 118: 'строите', 119: 'эту', 120: 'позитивного', 121: 'отношения', 122: 'чудеса', 123: 'способности', 124: 'достичь', 125: 'оставайся', 126: 'доверяй', 127: 'твой', 128: 'вещи', 129: 'приносят', 130: 'радость', 131: 'верь', 132: 'опыт', 133: 'отношение', 134: 'собираетесь', 135: 'выбор', 136: 'позитивный', 137: 'всю', 138: 'свое', 139: 'время', 140: 'обиды', 141: 'думаете', 142: 'потому', 143: 'каждый', 144: 'позитивные', 145: 'позитивной', 146: 'можем', 147: 'позитивную', 148: 'станет', 149: 'контролируете', 150: 'будьте', 151: 'возможности', 152: 'таланты', 153: 'были', 154: 'из', 155: 'два', 156: 'должен', 157: 'превращай', 158: 'которую', 159: 'стать', 160: 'делает', 161: 'человека', 162: 'нужны', 163: 'либо', 164: 'всем', 165: 'настроем', 166: 'почему', 167: 'позитивность', 168: 'самое', 169: 'главное', 170: 'один', 171: 'сейчас', 172: 'вокруг', 173: 'бы', 174: 'кому', 175: 'нужен', 176: 'внешностью', 177: 'могу', 178: 'точно', 179: 'поэтому', 180: 'даже', 181: 'такая', 182: 'любит', 183: 'плохая', 184: 'мой', 185: 'этого', 186: 'тут', 187: 'этих', 188: 'тогда', 189: 'болею', 190: 'бывает', 191: 'хоть', 192: 'бывают', 193: 'заработать', 194: 'платить', 195: 'богатство', 196: 'зависти', 197: 'думайте', 198: 'способность', 199: 'достигать', 200: 'отличных', 201: 'результатов', 202: 'лучший', 203: 'ответ', 204: 'проблемы', 205: 'возникли', 206: 'смогли', 207: 'постели', 208: 'супер', 209: 'герой', 210: 'твои', 211: 'утренние', 212: 'мысли', 213: 'задают', 214: 'тон', 215: 'всей', 216: 'твоей', 217: 'неделе', 218: 'увидеть', 219: 'становишься', 220: 'сильнее', 221: 'живешь', 222: 'счастливой', 223: 'полноценной', 224: 'утренним', 225: 'проблемам', 226: 'помешать', 227: 'успешным', 228: 'тяжелые', 229: 'часто', 230: 'приводят', 231: 'моментам', 232: 'трудности', 233: 'концов', 234: 'создают', 235: 'независимо', 236: 'через', 237: 'проходите', 238: 'туннеля', 239: 'показаться', 240: 'добраться', 241: 'него', 242: 'сложно', 243: 'сможете', 244: 'говорите', 245: 'хочу', 246: 'реальность', 247: 'принятие', 248: 'ко', 249: 'всему', 250: 'происходящему', 251: 'творить', 252: 'настроение', 253: 'добавляет', 254: 'годы', 255: 'весну', 256: 'вашему', 257: 'шагу', 258: 'искорку', 259: 'ваших', 260: 'глазах', 261: 'природные', 262: 'важны', 263: 'многого', 264: 'целеустремленность', 265: 'окружите', 266: 'позитивными', 267: 'людьми', 268: 'верят', 269: 'поддерживают', 270: 'идеи', 271: 'прости', 272: 'инвестируй', 273: 'своим', 274: 'инстинктам', 275: 'позволяй', 276: 'другим', ...

# %%
dist = list(tokenizer.word_counts.items())
print(dist[:10])
print(texts[0][:100])
# Out:
# [('думайте', 1), ('позитивно', 4), ('и', 50), ('верьте', 3), ('в', 38), ('свою', 4), ('способность', 1), ('достигать', 1), ('отличных', 1), ('результатов', 1)]
# Думайте позитивно и верьте в свою способность достигать отличных результатов.

# %%
max_text_len = 10
data = tokenizer.texts_to_sequences(texts)
data_pad = pad_sequences(data, maxlen = max_text_len)
print(data_pad)

#print( list(tokenizer.word_index.items()) )
# Out:
# [[197  54   2 ... 199 200 201]
#  [  0   4 202 ... 205   3  67]
#  [206   3  67 ...   4 208 209]
#  ...
#  [  0  20  62 ...  53 850 851]
#  [  0   0  43 ...  33   1 853]
#  [  0   0   0 ...  70  65 194]]

# %%
X_data = data_pad
#Y_data = np.array([[1, 0]]*count_true + [[0, 1]]*count_false)
Y_data = np.array([1]*count_true + [0]*count_false)
print(X_data.shape, Y_data.shape)

#indeces = np.random.choice(X_data.shape[0], size = X_data.shape[0], replace=False)
indeces = np.random.choice(X_data.shape[0], size = X_data.shape[0], replace=False)
#print(indeces)
X_data = X_data[indeces]
Y_data = Y_data[indeces]

factor = int(.80 * X_data.shape[0])

#X_test = X_data[round(len(X_data) * 0,9):]
#Y_test = Y_data[round(len(Y_data) * 0,9):]

#X_train = X_data[:round(len(X_data) * 0,9)]
#Y_train = Y_data[:round(len(Y_data) * 0,9)]

X_train,Y_train,X_test,Y_test = split(X_data,Y_data,factor)

#print(data_pad.shape)
#print("indeces: ", indeces)
print("train: ", X_train.shape, Y_train.shape)
print("test: ", X_test.shape, Y_test.shape)

#for x in range(100):
#    print(sequence_to_text(X_train[x]), f"\t[{Y_train[x]}]")
# Out:
# (172, 10) (172,)
# train:  (137, 10) (137,)
# test:  (35, 10) (35,)

# %%
#print(X.shape)
#LSTM?
#Sequential.compile?

# %%
model = Sequential()
model.add(Embedding(maxWordsCount, 128, input_length = max_text_len))
    #model.add(Embedding(maxWordsCount, 64, input_length = max_text_len))
model.add(LSTM(128, return_sequences=True, dropout = 0.3))
    #model.add(LSTM(256, return_sequences=True, dropout = 0.3))
model.add(LSTM(64, dropout = 0.3))
    #model.add(Dense(2, activation='softmax'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 10, 128)           128000
# _________________________________________________________________
# lstm (LSTM)                  (None, 10, 128)           131584
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 309,057
# Trainable params: 309,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Создание и настройка колбэков
callback_list = [] # массив колбэков до подачи в колбек "callbacklist"

temp = keras.callbacks.EarlyStopping(
            monitor = ES_monitor_parametr, 
            min_delta = ES_min_delta, 
            patience = ES_patience,
            restore_best_weights = ES_save_best_weights
            )
callback_list.append(temp)

temp = keras.callbacks.ReduceLROnPlateau(
            monitor = RLPOP_monitor_parametr, 
            factor = RLPOP_factor, 
            patience = RLPOP_patience, 
            verbose = RLPOP_verbose,
            mode = RLPOP_mode, 
            min_delta = RLPOP_min_delta, 
            cooldown = RLPOP_cooldown, 
            min_lr = RLPOP_min_lr
            )
callback_list.append(temp)

FIT_callback_list = keras.callbacks.CallbackList(
            callbacks = callback_list, 
            add_history = CBL_add_history, 
            add_progbar = CBL_add_progbar, 
            model = model
            )

# %%
model.compile(loss = 'binary_crossentropy',#'mean_squared_error', 
              metrics=['accuracy'], 
              # learning_rate = 0.1
              optimizer = tf.keras.optimizers.SGD(learning_rate = 0.05)) #Adam(0.0003)) #'categorical_crossentropy'

# %%
FIT_batch_size = 8 #15
history = model.fit(X_train, 
                    Y_train, 
                    batch_size = FIT_batch_size, 
                    shuffle = True, 
                    verbose = 1, 
                    epochs = 70, #30, 
                    validation_split = 0.20,
                    callbacks = FIT_callback_list)
# Out:
# 14/14 [==============================] - 1s 95ms/step - loss: 0.6954 - accuracy: 0.5138 - val_loss: 0.6951 - val_accuracy: 0.3571
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6939 - accuracy: 0.5138 - val_loss: 0.6964 - val_accuracy: 0.3571
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6924 - accuracy: 0.5505 - val_loss: 0.7036 - val_accuracy: 0.3571
# 14/14 [==============================] - 0s 10ms/step - loss: 0.6902 - accuracy: 0.5138 - val_loss: 0.6926 - val_accuracy: 0.4643
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6888 - accuracy: 0.6330 - val_loss: 0.6970 - val_accuracy: 0.3571
# 14/14 [==============================] - 0s 10ms/step - loss: 0.6893 - accuracy: 0.5229 - val_loss: 0.6888 - val_accuracy: 0.5714
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6876 - accuracy: 0.5688 - val_loss: 0.6868 - val_accuracy: 0.6071
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6849 - accuracy: 0.6239 - val_loss: 0.6882 - val_accuracy: 0.5714
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6848 - accuracy: 0.6055 - val_loss: 0.6810 - val_accuracy: 0.6786
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6827 - accuracy: 0.6330 - val_loss: 0.6880 - val_accuracy: 0.5357
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6778 - accuracy: 0.6697 - val_loss: 0.6860 - val_accuracy: 0.5357
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6749 - accuracy: 0.6055 - val_loss: 0.6655 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6726 - accuracy: 0.6789 - val_loss: 0.6552 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6689 - accuracy: 0.6881 - val_loss: 0.6431 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6634 - accuracy: 0.6972 - val_loss: 0.6397 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.6515 - accuracy: 0.6789 - val_loss: 0.6492 - val_accuracy: 0.7143
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6420 - accuracy: 0.7156 - val_loss: 0.6355 - val_accuracy: 0.7143
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6320 - accuracy: 0.7156 - val_loss: 0.6070 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6170 - accuracy: 0.7615 - val_loss: 0.5999 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6014 - accuracy: 0.7248 - val_loss: 0.5618 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5914 - accuracy: 0.7431 - val_loss: 0.5419 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5761 - accuracy: 0.7339 - val_loss: 0.5906 - val_accuracy: 0.7143
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5739 - accuracy: 0.7431 - val_loss: 0.5469 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5580 - accuracy: 0.7615 - val_loss: 0.5581 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5565 - accuracy: 0.7156 - val_loss: 0.4882 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5496 - accuracy: 0.7615 - val_loss: 0.4830 - val_accuracy: 0.8214
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5516 - accuracy: 0.7706 - val_loss: 0.4667 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5308 - accuracy: 0.7798 - val_loss: 0.4891 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5295 - accuracy: 0.7523 - val_loss: 0.4593 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5252 - accuracy: 0.7339 - val_loss: 0.4767 - val_accuracy: 0.8214
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5209 - accuracy: 0.7523 - val_loss: 0.4731 - val_accuracy: 0.8214
# 14/14 [==============================] - 0s 11ms/step - loss: 0.5051 - accuracy: 0.7798 - val_loss: 0.4486 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5063 - accuracy: 0.7523 - val_loss: 0.4470 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4845 - accuracy: 0.7706 - val_loss: 0.4470 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4725 - accuracy: 0.7982 - val_loss: 0.4424 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4708 - accuracy: 0.8257 - val_loss: 0.4389 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4517 - accuracy: 0.8257 - val_loss: 0.4526 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4386 - accuracy: 0.8257 - val_loss: 0.4341 - val_accuracy: 0.8214
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4103 - accuracy: 0.8440 - val_loss: 0.4258 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3929 - accuracy: 0.8257 - val_loss: 0.5798 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3652 - accuracy: 0.8807 - val_loss: 0.6089 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3975 - accuracy: 0.8440 - val_loss: 0.4305 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3168 - accuracy: 0.8807 - val_loss: 0.4382 - val_accuracy: 0.8214
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2897 - accuracy: 0.9358 - val_loss: 0.4255 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3142 - accuracy: 0.8991 - val_loss: 0.4290 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 13ms/step - loss: 0.2367 - accuracy: 0.9266 - val_loss: 0.4272 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1953 - accuracy: 0.9358 - val_loss: 0.4676 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3253 - accuracy: 0.8991 - val_loss: 0.4716 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 13ms/step - loss: 0.2553 - accuracy: 0.9358 - val_loss: 0.4223 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 13ms/step - loss: 0.2222 - accuracy: 0.9266 - val_loss: 0.5421 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1977 - accuracy: 0.9450 - val_loss: 0.5949 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1627 - accuracy: 0.9541 - val_loss: 0.4380 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1780 - accuracy: 0.9266 - val_loss: 0.8111 - val_accuracy: 0.4643
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2186 - accuracy: 0.9358 - val_loss: 0.4536 - val_accuracy: 0.8214
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1965 - accuracy: 0.9266 - val_loss: 0.4693 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1599 - accuracy: 0.9266 - val_loss: 0.4672 - val_accuracy: 0.7500
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1585 - accuracy: 0.9633 - val_loss: 0.4654 - val_accuracy: 0.8214
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1361 - accuracy: 0.9633 - val_loss: 2.1502 - val_accuracy: 0.3571
#  8/14 [================>.............] - ETA: 0s - loss: 0.4044 - accuracy: 0.8750
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.005000000074505806.
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2713 - accuracy: 0.9174 - val_loss: 0.4317 - val_accuracy: 0.8214
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1225 - accuracy: 0.9725 - val_loss: 0.4375 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1259 - accuracy: 0.9633 - val_loss: 0.4427 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1195 - accuracy: 0.9633 - val_loss: 0.4350 - val_accuracy: 0.8214
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1127 - accuracy: 0.9725 - val_loss: 0.4399 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1067 - accuracy: 0.9725 - val_loss: 0.4422 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1063 - accuracy: 0.9725 - val_loss: 0.4534 - val_accuracy: 0.7857
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0955 - accuracy: 0.9817 - val_loss: 0.4371 - val_accuracy: 0.8571
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1100 - accuracy: 0.9725 - val_loss: 0.4409 - val_accuracy: 0.8214
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1048 - accuracy: 0.9725 - val_loss: 0.4423 - val_accuracy: 0.8214
# 11/14 [======================>.......] - ETA: 0s - loss: 0.1202 - accuracy: 0.9659
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.0004999999888241291.
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1081 - accuracy: 0.9725 - val_loss: 0.4454 - val_accuracy: 0.8214
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1079 - accuracy: 0.9725 - val_loss: 0.4452 - val_accuracy: 0.8214

# %%
#Sequential.fit?

# %%
#reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

# %%
#t = "негативы".lower()
#data = tokenizer.texts_to_sequences([t])
#print(data)
#data_pad = pad_sequences(data, maxlen=max_text_len)
#print( sequence_to_text(data[0]) )
print(X_test)
for x in range(len(X_test)): 
    res = model.predict(' '.join(X_test[x]))
        #print(' '.join(sequence_to_text(x)))
    mark = "Положительно" if np.mean(res) > 0.5 else "Отрицательно"
    mark2 = "Положительно" if Y_test[x] == 1 else "Отрицательно"
    equal = "==" if mark == mark2 else "  "
    print((f"Maybe[{mark}] [%.4f] " % np.mean(res)) + equal + f" Right[{mark2}]\t" + 
          ' '.join(list(filter(None, sequence_to_text(X_test[x])))) )
    print(res)
        #print("res: ", res )
        #print("Положительно" if np.argmax(res) == 1 else "отрицательно")
# Out:
# [[  2 123  28   1  61  24 415  89 416  73]
#  [  0   0   0   0 595   6  75   1 131  39]
#  [  0 163  41 518  44 163  44 519  27 520]
#  [780  11  19 781   1 782  10  97 783 784]
#  [  0   0   1  69 224 225 226  28  32 227]
#  [  0   0   0   0   0  20  26 181 183 625]
#  [  0   0  98 170 662   1 663 664 665 666]
#  [  0   0  19 657   8 658 659 660 661 101]
#  [  0   0   0   0 681 682 683 684  43  26]
#  [ 47  10 146 376 147  86   3 377 378  13]
#  [  0  79   8 713 186  99 714 715   2 140]
#  [ 53  42  21 196  16  21 196  42  21 101]
#  [341 342 343 344  12   1 345 346  80 347]
#  [ 23 428 154 429 430  29   1 431  22 432]
#  [ 12   4  14 445   5 446   2 447 136 448]
#  [  3 764   1 765 179  74  10   3 766 767]
#  [  0   0   0  15 653 654   8 655   2 656]
#  [  0   0   0   0   0   0  26  50   1 182]
#  [218  40  41 219 220   2 221 222 223 103]
#  [ 45 133  10  11 312  12   4 134 313  77]
#  [318   3 319  18  32  38   2 320 321 130]
#  [  0 143  44  68  15  38 165   2 524 525]
#  [ 70 573   3 574  15  38 575 576  19  94]
#  [125  38 271  73 272   3  22 126 273 274]
#  [  0   4 202 203   5 204  56 205   3  67]
#  [ 12   4  14 351   5  13  54 352 144 128]
#  [  0  31 622 623   9   4  11 178   1 624]
#  [ 24  66   3  22   2 330  27 331  46 332]
#  [ 39   1 632  11  96   8 633 186  99 634]
#  [  0   0   0   0   0   0   0 739  10 740]
#  [  0 228 104 229 230  19 105 231 106  33]
#  [  0   0  93 796 797   5 117 798   1 799]
#  [753  64   1 754   5  22 755   1 756 757]
#  [  0   0 495   1 160 161 496  16 497 498]
#  [  0  40 173   6   1 602  30 603   1 604]]
# WARNING:tensorflow:Model was constructed with shape (None, 10) for input Tensor("embedding_input:0", shape=(None, 10), dtype=float32), but it was called on an input with incompatible shape (None, 1).
# Maybe[Положительно] [0.5921] == Right[Положительно]	и способности вам не нужно всегда идти по стопам других
# [[0.5740941 ]
#  [0.6002728 ]
#  [0.613903  ]
#  [0.51729816]
#  [0.6172501 ]
#  [0.64134604]
#  [0.600054  ]
#  [0.56603956]
#  [0.5988614 ]
#  [0.5916857 ]]
# Maybe[Положительно] [0.5698]    Right[Отрицательно]	говорила я тебе не верь никому
# [[0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5965413 ]
#  [0.5234614 ]
#  [0.5854348 ]
#  [0.51729816]
#  [0.6116517 ]
#  [0.5787227 ]]
# Maybe[Положительно] [0.5954] == Right[Положительно]	либо ты бежишь день либо день бежит за тобой
# [[0.5712648 ]
#  [0.59657824]
#  [0.6101481 ]
#  [0.5894004 ]
#  [0.61822075]
#  [0.59657824]
#  [0.61822075]
#  [0.58836156]
#  [0.5671029 ]
#  [0.5977682 ]]
# Maybe[Положительно] [0.5811]    Right[Отрицательно]	помогай это к добру не приведет все равно виноватым будешь
# [[0.5964646 ]
#  [0.5626057 ]
#  [0.62229276]
#  [0.6013677 ]
#  [0.51729816]
#  [0.60030615]
#  [0.54292816]
#  [0.5823121 ]
#  [0.59420675]
#  [0.5908819 ]]
# Maybe[Положительно] [0.5843] == Right[Положительно]	не позволяйте утренним проблемам помешать вам быть успешным
# [[0.5712648 ]
#  [0.5712648 ]
#  [0.51729816]
#  [0.6025584 ]
#  [0.5950578 ]
#  [0.59319925]
#  [0.59857523]
#  [0.613903  ]
#  [0.5803092 ]
#  [0.59922606]]
# Maybe[Положительно] [0.5762]    Right[Отрицательно]	у меня такая плохая карма
# [[0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.56603503]
#  [0.5710914 ]
#  [0.58487016]
#  [0.58854127]
#  [0.59515595]]
# Maybe[Положительно] [0.5828]    Right[Отрицательно]	ни один врач не сможет вылечить мою болезнь
# [[0.5712648 ]
#  [0.5712648 ]
#  [0.5858507 ]
#  [0.60708296]
#  [0.5943343 ]
#  [0.51729816]
#  [0.5944661 ]
#  [0.591007  ]
#  [0.5888383 ]
#  [0.6065295 ]]
# Maybe[Положительно] [0.5793]    Right[Отрицательно]	к врачам только попади сразу найдут кучу болезней
# [[0.5712648 ]
#  [0.5712648 ]
#  [0.62229276]
#  [0.5908301 ]
#  [0.5193861 ]
#  [0.5974176 ]
#  [0.5953461 ]
#  [0.58871627]
#  [0.58759815]
#  [0.5491133 ]]
# Maybe[Положительно] [0.5805]    Right[Отрицательно]	здоровое питание сильно дорого для меня
# [[0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.59444   ]
#  [0.5969372 ]
#  [0.58897567]
#  [0.5892401 ]
#  [0.5794619 ]
#  [0.5710914 ]]
# Maybe[Положительно] [0.5921] == Right[Положительно]	мы все можем привнести позитивную энергию в нашу повседневную жизнь
# [[0.6345935 ]
#  [0.54292816]
#  [0.6065832 ]
#  [0.59872514]
#  [0.59194505]
#  [0.58513045]
#  [0.53397155]
#  [0.5949213 ]
#  [0.5934183 ]
#  [0.6389279 ]]
# Maybe[Положительно] [0.5836]    Right[Отрицательно]	стоит только пожениться тут же начинаются ссора и обиды
# [[0.5712648 ]
#  [0.58972055]
#  [0.5193861 ]
#  [0.6059192 ]
#  [0.5960544 ]
#  [0.5840924 ]
#  [0.6060012 ]
#  [0.5901498 ]
#  [0.5740941 ]
#  [0.5993285 ]]
# Maybe[Положительно] [0.5890]    Right[Отрицательно]	денег тем больше зависти чем больше зависти тем больше болезней
# [[0.5393877 ]
#  [0.5993567 ]
#  [0.6097968 ]
#  [0.59538263]
#  [0.5825873 ]
#  [0.6097968 ]
#  [0.59538263]
#  [0.5993567 ]
#  [0.6097968 ]
#  [0.5491133 ]]
# Maybe[Положительно] [0.5824] == Right[Положительно]	узнаете весь свой потенциал если не будете бросать себе вызов
# [[0.59389246]
#  [0.59431463]
#  [0.5974438 ]
#  [0.584653  ]
#  [0.57700086]
#  [0.51729816]
#  [0.5898435 ]
#  [0.5931791 ]
#  [0.5815511 ]
#  [0.59498376]]
# Maybe[Положительно] [0.5871] == Right[Положительно]	то положительное из тех дней когда не чувствуете себя хорошо
# [[0.57458997]
#  [0.5907843 ]
#  [0.6038496 ]
#  [0.5954347 ]
#  [0.59596217]
#  [0.584335  ]
#  [0.51729816]
#  [0.5949504 ]
#  [0.6172611 ]
#  [0.5967271 ]]
# Maybe[Положительно] [0.6095] == Right[Положительно]	если вы просто сосредоточитесь на цели и сохраните позитивный настрой
# [[0.57700086]
#  [0.6809926 ]
#  [0.65439373]
#  [0.5879251 ]
#  [0.6425456 ]
#  [0.5910799 ]
#  [0.5740941 ]
#  [0.5847226 ]
#  [0.60774183]
#  [0.59469646]]
# Maybe[Положительно] [0.5702]    Right[Отрицательно]	в лес не убежит поэтому делай все в последний момент
# [[0.53397155]
#  [0.5980128 ]
#  [0.51729816]
#  [0.59277093]
#  [0.59432423]
#  [0.5918747 ]
#  [0.54292816]
#  [0.53397155]
#  [0.60217077]
#  [0.59451693]]
# Maybe[Положительно] [0.5790]    Right[Отрицательно]	с возрастом болячки только усиливаются и увеличиваются
# [[0.5712648]
#  [0.5712648]
#  [0.5712648]
#  [0.6083536]
#  [0.5995217]
#  [0.5961451]
#  [0.5193861]
#  [0.584509 ]
#  [0.5740941]
#  [0.5939273]]
# Maybe[Положительно] [0.5704]    Right[Отрицательно]	меня никто не любит
# [[0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5710914 ]
#  [0.59472317]
#  [0.51729816]
#  [0.5932338 ]]
# Maybe[Положительно] [0.5975] == Right[Положительно]	увидеть как ты становишься сильнее и живешь счастливой полноценной жизнью
# [[0.5909248 ]
#  [0.63783455]
#  [0.6101481 ]
#  [0.601532  ]
#  [0.58494455]
#  [0.5740941 ]
#  [0.58739257]
#  [0.5919101 ]
#  [0.5946251 ]
#  [0.601701  ]]
# Maybe[Положительно] [0.5964] == Right[Положительно]	позитивное отношение все это важно если вы собираетесь добиться успеха
# [[0.59856504]
#  [0.5989477 ]
#  [0.54292816]
#  [0.5626057 ]
#  [0.60159564]
#  [0.57700086]
#  [0.6809926 ]
#  [0.59946156]
#  [0.596531  ]
#  [0.60521555]]
# Maybe[Положительно] [0.5930] == Right[Положительно]	заключается в том чтобы быть позитивным и обнадеживающим выбирая радость
# [[0.5905494 ]
#  [0.53397155]
#  [0.5968535 ]
#  [0.60699326]
#  [0.5803092 ]
#  [0.6604889 ]
#  [0.5740941 ]
#  [0.5971279 ]
#  [0.6024716 ]
#  [0.58728063]]
# Maybe[Положительно] [0.6049] == Right[Положительно]	каждый день живи с позитивным настроем и пытайся улучшиться
# [[0.5712648 ]
#  [0.61196154]
#  [0.61822075]
#  [0.61237323]
#  [0.6083536 ]
#  [0.6604889 ]
#  [0.60407424]
#  [0.5740941 ]
#  [0.5989786 ]
#  [0.5895473 ]]
# Maybe[Положительно] [0.5988] == Right[Положительно]	хорошее действие в сочетании с позитивным мышлением приводит к успеху
# [[0.59826756]
#  [0.59759265]
#  [0.53397155]
#  [0.5929508 ]
#  [0.6083536 ]
#  [0.6604889 ]
#  [0.5913622 ]
#  [0.59773475]
#  [0.62229276]
#  [0.5854425 ]]
# Maybe[Положительно] [0.5985] == Right[Положительно]	оставайся позитивным прости других инвестируй в себя доверяй своим инстинктам
# [[0.6040757 ]
#  [0.6604889 ]
#  [0.59888464]
#  [0.5916857 ]
#  [0.5959361 ]
#  [0.53397155]
#  [0.6172611 ]
#  [0.58927065]
#  [0.5954118 ]
#  [0.59763044]]
# Maybe[Положительно] [0.6016] == Right[Положительно]	вы лучший ответ на проблемы которые возникли в понедельник
# [[0.5712648 ]
#  [0.6809926 ]
#  [0.59337753]
#  [0.5984037 ]
#  [0.6425456 ]
#  [0.5910053 ]
#  [0.61459327]
#  [0.5869961 ]
#  [0.53397155]
#  [0.60238165]]
# Maybe[Положительно] [0.6176] == Right[Положительно]	если вы просто посмотрите на жизнь позитивно произойдут позитивные вещи
# [[0.57700086]
#  [0.6809926 ]
#  [0.65439373]
#  [0.5930432 ]
#  [0.6425456 ]
#  [0.6389279 ]
#  [0.6019208 ]
#  [0.59147304]
#  [0.59827054]
#  [0.5973836 ]]
# Maybe[Положительно] [0.5911]    Right[Отрицательно]	мне публично выступить что вы это точно не мое
# [[0.5712648 ]
#  [0.574706  ]
#  [0.59691364]
#  [0.59883654]
#  [0.62224615]
#  [0.6809926 ]
#  [0.5626057 ]
#  [0.587107  ]
#  [0.51729816]
#  [0.5991727 ]]
# Maybe[Положительно] [0.5897] == Right[Положительно]	всегда верьте в себя и выходите за пределы своих возможностей
# [[0.64134604]
#  [0.5966092 ]
#  [0.53397155]
#  [0.6172611 ]
#  [0.5740941 ]
#  [0.5916889 ]
#  [0.5671029 ]
#  [0.59650004]
#  [0.5900593 ]
#  [0.58882296]]
# Maybe[Положительно] [0.5736]    Right[Отрицательно]	никому не доверяю это опасно только понадеешься тут же подведут
# [[0.5787227 ]
#  [0.51729816]
#  [0.5968397 ]
#  [0.5626057 ]
#  [0.58786356]
#  [0.5193861 ]
#  [0.59896195]
#  [0.5960544 ]
#  [0.5840924 ]
#  [0.5938632 ]]
# Maybe[Положительно] [0.5725]    Right[Отрицательно]	мужики все бесчувственные
# [[0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.5712648 ]
#  [0.59191954]
#  [0.54292816]
#  [0.59149426]]
# Maybe[Положительно] [0.5957] == Right[Положительно]	тяжелые времена часто приводят к величайшим моментам вашей жизни
# [[0.5712648 ]
#  [0.58713686]
#  [0.59465885]
#  [0.5968626 ]
#  [0.5945443 ]
#  [0.62229276]
#  [0.60280323]
#  [0.59745264]
#  [0.60413224]
#  [0.585937  ]]
# Maybe[Положительно] [0.5842]    Right[Отрицательно]	во столько лет на хорошую работу не устроиться
# [[0.5712648 ]
#  [0.5712648 ]
#  [0.57894874]
#  [0.5928831 ]
#  [0.58831453]
#  [0.6425456 ]
#  [0.5977529 ]
#  [0.5904049 ]
#  [0.51729816]
#  [0.59123534]]
# Maybe[Положительно] [0.5839]    Right[Отрицательно]	наказуема лучше не бери на себя лишнего не подводи коллег
# [[0.58847314]
#  [0.58476615]
#  [0.51729816]
#  [0.59465647]
#  [0.6425456 ]
#  [0.6172611 ]
#  [0.59416074]
#  [0.51729816]
#  [0.5923123 ]
#  [0.5902231 ]]
# Maybe[Положительно] [0.5803] == Right[Положительно]	ничто не делает человека счастливее чем счастливое сердце
# [[0.5712648 ]
#  [0.5712648 ]
#  [0.58225113]
#  [0.51729816]
#  [0.59558576]
#  [0.5918103 ]
#  [0.5978515 ]
#  [0.5825873 ]
#  [0.59513366]
#  [0.5974832 ]]
# Maybe[Положительно] [0.5726]    Right[Отрицательно]	как бы я не старался от судьбы не уйдешь
# [[0.5712648 ]
#  [0.63783455]
#  [0.6014094 ]
#  [0.5234614 ]
#  [0.51729816]
#  [0.5958212 ]
#  [0.58188885]
#  [0.58903366]
#  [0.51729816]
#  [0.5908475 ]]

# %%
# Вывод графика изменения ошибки
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc = 'upper left')
plt.show()

# %%
# тест модели
model.evaluate(X_test, Y_test, batch_size = FIT_batch_size)
# Out:
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4370 - accuracy: 0.8000
# [0.43697527050971985, 0.800000011920929]

# %%
# Вывод графика изменения ошибки
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc = 'upper left')
plt.show()

# %%
t = "если вы просто посмотрите на жизнь позитивно произойдут позитивные вещи".lower()
data = tokenizer.texts_to_sequences([t])
print(data)
data_pad = pad_sequences(data, maxlen = max_text_len)
print( sequence_to_text(data[0]) )

res = model.predict(data_pad)

mark = "Положительно" if  > 0.5 else "отрицательно"
print(f"[{mark}]")

print(res[0,0])
# Out:
# [[12, 4, 14, 351, 5, 13, 54, 352, 144, 128]]
# ['если', 'вы', 'просто', 'посмотрите', 'на', 'жизнь', 'позитивно', 'произойдут', 'позитивные', 'вещи']
# [Положительно]
# 0.9974206

# %%
t = "это просто ужасно плохо противно не хорошо".lower()
data = tokenizer.texts_to_sequences([t])
print(data)
data_pad = pad_sequences(data, maxlen = max_text_len)
print( sequence_to_text(data[0]) )

res = model.predict(data_pad)

mark = "Положительно" if np.mean(res) > 0.5 else "отрицательно"
print(f"[{mark}]")

print(res)
print(res[0,0])
# Out:
# [[11, 14, 677, 1, 432]]
# ['это', 'просто', 'плохо', 'не', 'хорошо']
# [отрицательно]
# [[0.2102184]]
# 0.2102184
